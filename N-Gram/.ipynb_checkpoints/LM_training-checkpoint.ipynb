# %%
import sys 
import os
from tokenizer import Tokenizer
import re
from scipy.stats import linregress
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pickle
np.random.seed(42)

# %%
class Ngram():
    def __init__(self, N=3, smoothing = None, remove_punctuations = True):
        self.N = N
        self.smoothing = smoothing
        self.remove_punctuations = remove_punctuations
        self.counts_dict = None

    def punctuation_remover(self, text):
        '''removes punctuation only tokens and also punctuations within tokens'''
        new_text = []
        for sentence in text:
            new_sentence = []
            for word in sentence:
                word = re.sub(r'([^\w\s><\']|_)','',word).strip()
                if len(word) != 0:
                    new_sentence.append(word)
            new_text.append(new_sentence)
        return new_text

    def sentence_to_ngram(self, sentence, n):
        '''Takes sentence(list of tokens) and n(order) as input and retuns ngrams.'''
        n_grams = []
        for i in range(len(sentence)-n+1):
            n_gram = " ".join(sentence[i:i+n])
            n_grams.append(n_gram)
        return n_grams
        
    def ngram_counter(self, tokenized_text, n):
        '''Takes tokenized_text(list of list of tokens[for each sentence]) and n(order) as input and returns ngram counts.'''
        counts_dict = {}
        for sentence in tokenized_text:
            for n_gram in self.sentence_to_ngram(sentence,n):
                if n_gram in counts_dict:
                    counts_dict[n_gram] += 1
                else:
                    counts_dict[n_gram] = 1
        return counts_dict

    def train(self, corpus_path):
        '''Takes N(order) and corpus_path as input and return ngram counts from n = 1:N'''
        self.corpus_path = corpus_path
        f = open(corpus_path,'r',encoding='utf8')
        text = f.read()
        f.close()
        tokenized_text = Tokenizer(text).tokenized_text
        random.shuffle(tokenized_text)
        self.train_set, self.test_set = tokenized_text[:-1000], tokenized_text[-1000:]
        
        if self.remove_punctuations:
            self.train_set = self.punctuation_remover(self.train_set)
            self.test_set = self.punctuation_remover(self.test_set)
            
        self.train_set = [['<START>' for _ in range(self.N-1)] + sentence + ['<END>'] for sentence in self.train_set]
        ngram_counts = {}
        for n in range(1,self.N+1):
            ngram_counts[n] = self.ngram_counter(self.train_set,n)
        self.counts_dict = ngram_counts
        self.LinearInterpolation()
        self.GoodTuring()
    
    def GoodTuring(self):
        '''Creates r-Nr dictionary and fit a line for log(r)-log(Nr)'''
        nr = {}
        for n_gram in self.counts_dict[self.N]:
            r = self.counts_dict[self.N][n_gram]
            if r in nr:
                nr[r] += 1
            else:
                nr[r] = 1
        self.nr = dict(sorted(nr.items(), key=lambda item: item[1]))
        self.lr = linregress(np.log(list(lm.nr.keys())),np.log(list(lm.nr.values())))
        
    def LinearInterpolation(self):
        '''Estimates lambdas'''
        lambdas_t = [0 for _ in range(self.N)]
        n_tokens = sum(self.counts_dict[1].values())
        for n_gram in self.counts_dict[self.N]:
            words = n_gram.split()
            expression_values = []
            freqs = []
            for n_temp in range(1, self.N+1):
                if n_temp == 1:
                    expression_values.append(self.counts_dict[1][words[0]]/n_tokens)
                    freqs.append(self.counts_dict[1][words[0]])
                else:
                    n_gram_temp = " ".join(words[:n_temp])
                    n_gram_temp_lower = " ".join(words[:n_temp-1])
                    value = (self.counts_dict[n_temp][n_gram_temp]-1)/(self.counts_dict[n_temp-1][n_gram_temp_lower]-1) if self.counts_dict[n_temp-1][n_gram_temp_lower]!=1 else 0
                    expression_values.append(value)
                    freqs.append(self.counts_dict[n_temp][n_gram_temp])
                    
            max_n = expression_values.index(max(expression_values))
            lambdas_t[max_n] += freqs[max_n]
        sum_lambdas = sum(lambdas_t)
        self.lambdas = [lambda_v/sum_lambdas for lambda_v in lambdas_t]
        
    def score_ngram(self, n_gram):
        '''Returns probability of given Ngram based on the smoothing option'''
        if self.smoothing == None:
        # No smoothing
            context = " ".join(n_gram.split()[:-1])
            if n_gram in self.counts_dict[self.N]:
                if context in self.counts_dict[self.N-1]:
                    c_ngram = self.counts_dict[self.N][n_gram]
                    c_context = self.counts_dict[self.N-1][context]
                    return c_ngram/c_context
                else:
                    return 10e-5
            else:
                return 10e-5
        elif self.smoothing == 'i':
        #Linear interpolation scoring
            score_i = 0
            words = n_gram.split()
            for n_t in range(1, self.N+1):
                n_gram_t = " ".join(words[:n_t])
                if n_t == 1:
                    if n_gram_t in self.counts_dict[1]:
                        score_i += self.lambdas[0]*(self.counts_dict[1][n_gram_t]/sum(self.counts_dict[1].values()))
                    else:
                        score_i += self.lambdas[0]*10e-5  
                else:
                    context = " ".join(words[:n_t-1])
                    if n_gram_t in self.counts_dict[n_t]:
                        score_i += self.lambdas[n_t-1]*(self.counts_dict[n_t][n_gram_t]/self.counts_dict[n_t-1][context])
            return score_i

        elif self.smoothing == 'g':
        #Good Turing scoring
            context = " ".join(n_gram.split()[:-1])
            if context in self.counts_dict[self.N-1]:
                r = self.counts_dict[self.N][n_gram] if n_gram in self.counts_dict[self.N] else 0
                if 1<r<20:
                    r_star = (r+1)*(self.nr[r+1]/self.nr[r])
                else:
                    if r == 0:
                        r = 10e-5
                    r_star = (r+1)*(np.exp(self.lr.slope*np.log(r+1)+self.lr.intercept)/np.exp(self.lr.slope*np.log(r)+self.lr.intercept))
                return r_star/self.counts_dict[self.N-1][context]
            else:
                return 10e-5
            
    def score(self, sentence, return_probs = False):
        '''Takes LM(ngram_counts), N(order), sentence(tokenized) as input and return score'''
        tokenized_text = Tokenizer(sentence).tokenized_text
        if self.remove_punctuations:
            tokenized_text = self.punctuation_remover(tokenized_text)
        tokenized_text = ['<START>' for _ in range(self.N-1)] + tokenized_text[0] + ['<END>']
        scores = []
        for n_gram in self.sentence_to_ngram(tokenized_text, self.N):
            scores.append(self.score_ngram(n_gram))
            
        if return_probs == True:
            return sum(np.log(scores)), scores
        else:
            return sum(np.log(scores))

    def perplexity(self, sentence):
        '''returns perplexity of a given sentence'''
        score, probs = self.score(sentence, return_probs=True)
        return np.power(1/np.prod(probs), 1/len(probs))


    def generate(self,sentence, top_n = 3):
        '''returns top n probable words for next word given context'''
        tokenized_text = Tokenizer(sentence).tokenized_text
        if self.remove_punctuations:
            tokenized_text = self.punctuation_remover(tokenized_text)
        tokenized_text = ['<START>' for _ in range(self.N-1)] + tokenized_text[0]
        n_grams = self.sentence_to_ngram(tokenized_text, self.N)
        context = " ".join(n_grams[-1].split()[1:])
        words, scores = [], []
        for word in self.counts_dict[1]:
            if word != '<START>':
                n_gram_t = " ".join([context,word])
                scores.append(self.score_ngram(n_gram_t))
                words.append(word)
        sorted_indices = np.argsort(scores)[::-1]
        return {words[i]: scores[i] for i in sorted_indices[:top_n]}

    def evaluate(self):
        self.test_set = [['<START>' for _ in range(self.N-1)] + sentence + ['<END>'] for sentence in self.test_set]
        self.test_set_perplexity = {}
        for sentence in self.test_set:
            scores = []
            for n_gram in self.sentence_to_ngram(sentence, self.N):
                scores.append(self.score_ngram(n_gram))
            sentence = " ".join(sentence)
            if math.isinf(np.power(1/np.prod(scores), 1/len(scores))):
                # print(sentence)
                # print(scores)
                continue
            self.test_set_perplexity[sentence] = np.power(1/np.prod(scores), 1/len(scores))

        self.train_set_perplexity = {}
        for sentence in self.train_set:
            scores = []
            for n_gram in self.sentence_to_ngram(sentence, self.N):
                scores.append(self.score_ngram(n_gram))
            sentence = " ".join(sentence)
            if math.isinf(np.power(1/np.prod(scores), 1/len(scores))):
                # print(sentence)
                # print(scores)
                continue
            self.train_set_perplexity[sentence] = np.power(1/np.prod(scores), 1/len(scores))


        file_name = self.corpus_path.split("/")[-1].split(".")[0]+"_"+str(self.N)+"_"+self.smoothing+"_train.txt"
        f_train = open(file_name, 'w', encoding='utf8')
        f_train.write(str(sum(self.train_set_perplexity.values())/len(self.train_set_perplexity))+"\n")
        for sentence in self.train_set_perplexity:
            f_train.write(sentence+"\t"+str(self.train_set_perplexity[sentence])+"\n")
        f_train.close()

        file_name = self.corpus_path.split("/")[-1].split(".")[0]+"_"+str(self.N)+"_"+self.smoothing+"_test.txt"
        f_test = open(file_name, 'w', encoding='utf8')
        f_test.write(str(sum(self.test_set_perplexity.values())/len(self.test_set_perplexity))+"\n")
        for sentence in self.test_set_perplexity:
            f_test.write(sentence+"\t"+str(self.test_set_perplexity[sentence])+"\n")
        f_test.close()

    def save(self, file_name):
        with open(file_name, 'wb') as f:
            pickle.dump([self.counts_dict, self.lambdas, self.nr, self.lr], f)
    
    def load(self, file_name):
        with open(file_name, 'rb') as f:
            self.counts_dict, self.lambdas, self.nr, self.lr = pickle.load(f)

# %%
N = 3
corpus_path = "Corpuses/Pride_and_Prejudice-Jane_Austen.txt"

# %%
lm = Ngram(N=3, smoothing='i')
lm.train(corpus_path)

# %%
# lm.evaluate()

# %%
lm.perplexity("but she had never felt so strongly as now the disadvantages which must attend the children of so unsuitable a marriage nor ever been so fully aware of the evils arising from so ill judged a direction of talents talents which rightly used might at least have preserved the respectability of his daughters even if incapable of enlarging the mind of his wife")
# Out:
# 111.65116046460561

# %%
lm.save("test")

# %%
lm = Ngram(N=3, smoothing='g')
lm.load('test.pkl')

# %%
lm.counts_dict
# Out:
# {1: {'<START>': 10406,
#   'upon': 62,
#   'my': 610,
#   'word': 43,
#   'said': 349,
#   'mrs': 290,
#   'gardiner': 81,
#   'i': 1724,
#   'begin': 11,
#   'to': 3553,
#   'be': 1030,
#   'of': 3151,
#   'your': 413,
#   'uncle': 56,
#   "'s": 570,
#   'opinion': 57,
#   '<END>': 5203,
#   'elizabeth': 513,
#   'was': 1560,
#   'determined': 29,
#   'nor': 57,
#   'did': 227,
#   'sir': 69,
#   'william': 41,
#   'at': 666,
#   'all': 533,
#   'shake': 2,
#   'her': 1884,
#   'purpose': 19,
#   'by': 560,
#   'his': 1072,
#   'attempt': 20,
#   'persuasion': 6,
#   'mr': 658,
#   'bennet': 272,
#   'you': 1218,
#   'are': 306,
#   'wanted': 17,
#   'immediately': 49,
#   'we': 221,
#   'in': 1634,
#   'an': 323,
#   'uproar': 1,
#   'but': 834,
#   'when': 306,
#   'they': 498,
#   'see': 121,
#   'as': 1000,
#   'trust': 12,
#   'will': 349,
#   'that': 1341,
#   'their': 378,
#   'brother': 70,
#   'is': 756,
#   'happy': 68,
#   'with': 950,
#   'me': 385,
#   'learn': 10,
#   'contented': 4,
#   'and': 3086,
#   'shall': 142,
#   'on': 610,
#   'good': 174,
#   'terms': 37,
#   'again': 146,
#   'though': 190,
#   'can': 183,
#   'never': 187,
#   'what': 412,
#   'once': 51,
#   'were': 469,
#   'each': 51,
#   'other': 180,
#   'oh': 76,
#   'yes': 59,
#   'first': 125,
#   'had': 980,
#   'rather': 48,
#   'wondered': 8,
#   'charlotte': 79,
#   'should': 212,
#   'not': 1207,
#   'prefer': 5,
#   'the': 3776,
#   'dining': 15,
#   'parlour': 10,
#   'for': 914,
#   'common': 14,
#   'use': 23,
#   'it': 1287,
#   'a': 1709,
#   'better': 78,
#   'sized': 1,
#   'room': 126,
#   'pleasanter': 4,
#   'aspect': 5,
#   'she': 1446,
#   'soon': 184,
#   'saw': 89,
#   'friend': 94,
#   'excellent': 18,
#   'reason': 48,
#   'collins': 146,
#   'would': 387,
#   'undoubtedly': 10,
#   'have': 718,
#   'been': 444,
#   'much': 278,
#   'less': 65,
#   'own': 150,
#   'apartment': 4,
#   'sat': 32,
#   'one': 257,
#   'equally': 16,
#   'lively': 15,
#   'gave': 47,
#   'credit': 24,
#   'arrangement': 7,
#   'some': 172,
#   'days': 29,
#   'however': 110,
#   'before': 197,
#   'received': 58,
#   'any': 358,
#   'invitation': 28,
#   'thither': 7,
#   'while': 72,
#   'there': 294,
#   'visitors': 14,
#   'house': 91,
#   'could': 445,
#   'necessary': 26,
#   'till': 76,
#   'easter': 2,
#   'day': 118,
#   'almost': 50,
#   'week': 25,
#   'after': 171,
#   'gentlemen': 26,
#   'arrival': 28,
#   'honoured': 8,
#   'such': 332,
#   'attention': 60,
#   'then': 150,
#   'merely': 26,
#   'asked': 32,
#   'leaving': 16,
#   'church': 11,
#   'come': 81,
#   'evening': 63,
#   'from': 435,
#   'severity': 1,
#   'blame': 15,
#   'which': 453,
#   'last': 100,
#   'night': 28,
#   'so': 495,
#   'liberally': 2,
#   'bestowed': 8,
#   'respecting': 3,
#   'circumstance': 17,
#   'hope': 106,
#   'future': 15,
#   'secured': 2,
#   'following': 21,
#   'account': 30,
#   'actions': 5,
#   'motives': 3,
#   'has': 197,
#   'read': 36,
#   'since': 47,
#   'father': 116,
#   'death': 7,
#   'home': 63,
#   'london': 47,
#   'where': 81,
#   'lady': 171,
#   'lives': 4,
#   'superintends': 1,
#   'education': 11,
#   'something': 61,
#   'told': 58,
#   'may': 174,
#   'remember': 19,
#   'am': 266,
#   'particularly': 30,
#   'unlucky': 9,
#   'meeting': 18,
#   'person': 49,
#   'well': 190,
#   'able': 49,
#   'expose': 5,
#   'real': 24,
#   'character': 55,
#   'part': 53,
#   'world': 53,
#   'hoped': 19,
#   'pass': 13,
#   'myself': 86,
#   'off': 51,
#   'degree': 20,
#   'several': 20,
#   'young': 108,
#   'men': 30,
#   'too': 125,
#   'likes': 7,
#   'very': 410,
#   'those': 46,
#   'who': 244,
#   'do': 305,
#   'complain': 3,
#   'pitied': 3,
#   'errors': 4,
#   'made': 120,
#   'public': 16,
#   'might': 175,
#   'ruin': 4,
#   'him': 646,
#   'ever': 117,
#   'difficult': 10,
#   'indeed': 86,
#   'distressing': 4,
#   'thought': 98,
#   'broke': 3,
#   'heart': 38,
#   'this': 414,
#   'period': 13,
#   'every': 236,
#   'appearance': 26,
#   'acquaintance': 53,
#   'dropt': 4,
#   'country': 37,
#   'he': 1124,
#   'replied': 90,
#   'wish': 87,
#   'leave': 55,
#   'town': 56,
#   'pretty': 22,
#   'same': 61,
#   'bingley': 268,
#   'obliged': 23,
#   'consequently': 10,
#   'unable': 13,
#   'accept': 17,
#   'honour': 36,
#   'c': 13,
#   'abominably': 4,
#   'rude': 3,
#   'keep': 24,
#   'out': 112,
#   'doors': 7,
#   'wind': 1,
#   'suppose': 43,
#   'sisters': 65,
#   'heard': 71,
#   'authority': 8,
#   'left': 52,
#   'conditionally': 2,
#   'only': 184,
#   'present': 58,
#   'patron': 2,
#   'mother': 111,
#   'how': 197,
#   'carriage': 37,
#   'remained': 22,
#   'door': 28,
#   'waiting': 9,
#   'woman': 57,
#   'expected': 33,
#   'knowledge': 15,
#   'affability': 4,
#   'happen': 12,
#   'give': 107,
#   'time': 179,
#   'reply': 19,
#   'hurrying': 3,
#   'instantly': 28,
#   'husband': 46,
#   'called': 38,
#   'entered': 33,
#   'library': 20,
#   'must': 273,
#   'expect': 31,
#   'jane': 248,
#   'fortune': 32,
#   'tempered': 5,
#   'man': 129,
#   'firmest': 2,
#   'way': 91,
#   'longbourn': 74,
#   'inquire': 2,
#   'addressing': 3,
#   'daughter': 72,
#   'consideration': 11,
#   'leads': 3,
#   'moreover': 10,
#   'reflect': 4,
#   'augmented': 1,
#   'satisfaction': 24,
#   'certain': 51,
#   'event': 21,
#   'november': 5,
#   'otherwise': 16,
#   'involved': 3,
#   'sorrow': 4,
#   'disgrace': 9,
#   'communication': 9,
#   'excited': 9,
#   'many': 111,
#   'professions': 5,
#   'concern': 21,
#   'enough': 89,
#   'wishing': 11,
#   'them': 364,
#   'stay': 33,
#   'least': 54,
#   'work': 55,
#   'morrow': 17,
#   'going': 51,
#   'deferred': 2,
#   'instinctively': 2,
#   'turned': 36,
#   'away': 97,
#   'stopping': 3,
#   'approach': 7,
#   'compliments': 11,
#   'embarrassment': 7,
#   'impossible': 41,
#   'overcome': 10,
#   'make': 141,
#   'both': 64,
#   'thing': 138,
#   'perfectly': 43,
#   'convinced': 29,
#   'darcy': 350,
#   'no': 426,
#   'defect': 7,
#   'astonishment': 25,
#   'beyond': 33,
#   'expression': 18,
#   'surprise': 31,
#   'great': 121,
#   'proceeding': 5,
#   'directly': 21,
#   'favourite': 15,
#   'walk': 45,
#   'recollection': 11,
#   'sometimes': 31,
#   'coming': 55,
#   'stopped': 5,
#   'instead': 19,
#   'entering': 6,
#   'park': 19,
#   'up': 107,
#   'lane': 9,
#   'led': 17,
#   'farther': 29,
#   'turnpike': 1,
#   'road': 12,
#   'complete': 7,
#   'favourable': 11,
#   'impression': 6,
#   'voluntarily': 6,
#   'done': 74,
#   'lydia': 147,
#   'avowed': 3,
#   'or': 316,
#   'whether': 44,
#   'sister': 180,
#   'still': 62,
#   'partial': 9,
#   'if': 306,
#   'confession': 3,
#   'coloured': 5,
#   'spoke': 32,
#   'neither': 32,
#   'else': 33,
#   'awakened': 4,
#   'suspicion': 9,
#   'truth': 20,
#   'mortal': 1,
#   'triumph': 9,
#   'prevented': 18,
#   'replying': 3,
#   'entrance': 13,
#   'footman': 1,
#   'note': 9,
#   'miss': 241,
#   'came': 72,
#   'netherfield': 59,
#   'servant': 17,
#   'waited': 5,
#   'answer': 59,
#   'whatever': 25,
#   'hurry': 10,
#   'therefore': 61,
#   'resolve': 2,
#   'quit': 8,
#   'probably': 17,
#   'five': 29,
#   'minutes': 32,
#   'now': 169,
#   'formal': 6,
#   'wave': 1,
#   'hand': 26,
#   'usual': 31,
#   'ladies': 56,
#   'reject': 4,
#   'addresses': 5,
#   'whom': 71,
#   'secretly': 3,
#   'mean': 32,
#   'applies': 1,
#   'favour': 18,
#   'refusal': 7,
#   'repeated': 18,
#   'second': 24,
#   'even': 70,
#   'third': 7,
#   'sensible': 30,
#   'gentleman': 43,
#   'like': 79,
#   'greatly': 11,
#   'superior': 17,
#   'nature': 20,
#   'passage': 2,
#   'hurts': 1,
#   'pursuing': 2,
#   'along': 7,
#   'began': 51,
#   'chapter': 49,
#   'xx': 1,
#   'long': 95,
#   'silent': 17,
#   'contemplation': 4,
#   'successful': 3,
#   'love': 80,
#   'having': 78,
#   'dawdled': 1,
#   'about': 105,
#   'vestibule': 4,
#   'watch': 2,
#   'end': 25,
#   'conference': 4,
#   'sooner': 12,
#   'open': 16,
#   'quick': 9,
#   'step': 14,
#   'towards': 60,
#   'staircase': 2,
#   'than': 248,
#   'breakfast': 24,
#   'congratulated': 2,
#   'herself': 176,
#   'warm': 5,
#   'prospect': 11,
#   'nearer': 5,
#   'connection': 16,
#   'objection': 13,
#   'receive': 28,
#   'into': 126,
#   'propose': 2,
#   'family': 127,
#   'monday': 8,
#   '18th': 1,
#   'four': 31,
#   'o': 4,
#   "'clock": 4,
#   'trespass': 1,
#   'hospitality': 2,
#   'saturday': 15,
#   'se': 2,
#   "'night": 2,
#   'without': 153,
#   'inconvenience': 6,
#   'catherine': 113,
#   'far': 54,
#   'objecting': 3,
#   'occasional': 5,
#   'absence': 23,
#   'sunday': 6,
#   'provided': 8,
#   'clergyman': 8,
#   'engaged': 31,
#   'duty': 13,
#   'talked': 31,
#   'more': 280,
#   'dinner': 28,
#   'satisfied': 29,
#   'manners': 42,
#   'design': 21,
#   'engaging': 6,
#   'affection': 48,
#   'remain': 10,
#   'christmas': 5,
#   'colonel': 46,
#   'fitzwilliam': 26,
#   'parsonage': 15,
#   'during': 22,
#   'seen': 63,
#   'reckoned': 1,
#   'proud': 19,
#   'people': 45,
#   'knew': 48,
#   'refusing': 7,
#   'hill': 9,
#   'fixed': 19,
#   'sixteen': 5,
#   'most': 158,
#   'flirt': 4,
#   'ridiculous': 3,
#   'nothing': 149,
#   'console': 9,
#   'appease': 1,
#   'gouldings': 2,
#   'three': 50,
#   'daughters': 42,
#   'married': 47,
#   'call': 23,
#   'ladyship': 36,
#   'escaped': 5,
#   'observation': 13,
#   'passing': 9,
#   'these': 62,
#   'visits': 4,
#   'acutely': 3,
#   'feel': 30,
#   'hurried': 10,
#   'back': 33,
#   'alarm': 13,
#   'supposing': 11,
#   'niece': 21,
#   'taken': 26,
#   'suddenly': 14,
#   'ill': 63,
#   'satisfying': 1,
#   'head': 25,
#   'eagerly': 9,
#   'communicated': 2,
#   'cause': 19,
#   'summons': 2,
#   'reading': 15,
#   'two': 118,
#   'letters': 14,
#   'aloud': 10,
#   'dwelling': 4,
#   'postscript': 3,
#   'trembling': 1,
#   'energy': 4,
#   "'": 38,
#   'tis': 2,
#   'etiquette': 2,
#   'despise': 3,
#   'wickham': 164,
#   'course': 41,
#   'get': 43,
#   'length': 25,
#   'reduced': 3,
#   'reasonable': 10,
#   'hear': 58,
#   'changing': 2,
#   'colour': 11,
#   'repeat': 5,
#   'marrying': 21,
#   'inclined': 9,
#   'misunderstood': 3,
#   'donations': 14,
#   'accepted': 15,
#   'number': 8,
#   'ways': 4,
#   'including': 9,
#   'checks': 1,
#   'online': 5,
#   'payments': 1,
#   'card': 9,
#   'stupidity': 3,
#   'favoured': 1,
#   'guard': 4,
#   'courtship': 2,
#   'charm': 6,
#   'its': 89,
#   'continuance': 3,
#   'lucas': 62,
#   'solely': 4,
#   'pure': 2,
#   'disinterested': 3,
#   'desire': 19,
#   'establishment': 6,
#   'cared': 7,
#   'gained': 10,
#   'divided': 3,
#   'between': 55,
#   'resentment': 13,
#   'against': 49,
#   'others': 48,
#   'deficient': 3,
#   'used': 18,
#   'true': 23,
#   'think': 176,
#   'caroline': 16,
#   'spirits': 31,
#   'words': 24,
#   'glad': 28,
#   'reproached': 2,
#   'giving': 20,
#   'notice': 21,
#   'gone': 52,
#   'contrary': 10,
#   'collection': 7,
#   'little': 161,
#   'beauty': 22,
#   'fashion': 5,
#   'none': 18,
#   'felt': 87,
#   'smallest': 9,
#   'interest': 25,
#   'either': 50,
#   'pleasure': 82,
#   'quite': 77,
#   'detest': 3,
#   'paused': 3,
#   'surely': 4,
#   'occasion': 34,
#   'exposing': 3,
#   'dreadfully': 2,
#   'weeks': 16,
#   'passed': 52,
#   'kent': 13,
#   'difference': 8,
#   'adding': 4,
#   'verdure': 1,
#   'early': 23,
#   'trees': 5,
#   'kitty': 59,
#   'upstairs': 1,
#   'sit': 11,
#   'dressing': 8,
#   'urged': 6,
#   'jones': 4,
#   'being': 149,
#   'sent': 17,
#   'advice': 10,
#   'service': 7,
#   'recommended': 8,
#   'express': 21,
#   'eminent': 1,
#   'physicians': 1,
#   'respect': 22,
#   'travellers': 3,
#   'found': 56,
#   'held': 4,
#   'estimation': 4,
#   'chief': 12,
#   'concerns': 7,
#   'son': 19,
#   'imperfectly': 1,
#   'understood': 11,
#   'yet': 58,
#   'known': 54,
#   'fact': 12,
#   'quitting': 7,
#   'derbyshire': 18,
#   'debts': 8,
#   'behind': 12,
#   'afterwards': 24,
#   'discharged': 2,
#   'satirical': 1,
#   'eye': 15,
#   'impertinent': 5,
#   'grow': 4,
#   'afraid': 27,
#   'offer': 23,
#   'lizzy': 84,
#   'certainly': 62,
#   'formed': 13,
#   'plan': 10,
#   'meaning': 13,
#   'affect': 4,
#   'endeavour': 20,
#   'separate': 6,
#   'probable': 12,
#   'add': 10,
#   'welfare': 5,
#   'subject': 76,
#   'warmly': 7,
#   'canvassed': 2,
#   'parents': 6,
#   'twelvemonth': 6,
#   'ago': 24,
#   'brought': 32,
#   'forward': 27,
#   'sincerely': 6,
#   'grieved': 10,
#   'f': 4,
#   'throw': 7,
#   'mistake': 6,
#   'sure': 90,
#   'modesty': 6,
#   'afternoon': 3,
#   'urgent': 3,
#   'rest': 36,
#   'girls': 37,
#   'meryton': 47,
#   'body': 46,
#   'went': 55,
#   'steadily': 2,
#   'opposed': 4,
#   'scheme': 17,
#   'hated': 4,
#   'evident': 10,
#   'acquainted': 23,
#   'idea': 45,
#   'envy': 3,
#   'himself': 107,
#   'natural': 19,
#   'unhappy': 11,
#   'state': 23,
#   'rendered': 9,
#   'excuse': 14,
#   'lowness': 1,
#   'unnecessary': 4,
#   'fairly': 2,
#   'conjectured': 2,
#   'tolerably': 10,
#   'feelings': 69,
#   'aware': 12,
#   'borne': 4,
#   'dread': 3,
#   'infamy': 3,
#   'somewhat': 8,
#   'united': 10,
#   'efforts': 4,
#   'unfeeling': 2,
#   'overpowering': 1,
#   'assisted': 4,
#   'attractions': 5,
#   'amusements': 2,
#   'feared': 9,
#   'strength': 5,
#   'attachment': 24,
#   'single': 11,
#   'large': 21,
#   'thousand': 29,
#   'year': 26,
#   'guess': 4,
#   'says': 13,
#   'ate': 4,
#   'pride': 44,
#   'dare': 35,
#   'say': 139,
#   'somehow': 1,
#   'does': 80,
#   'ball': 29,
#   'hack': 1,
#   'chaise': 7,
#   'quietly': 7,
#   'answered': 31,
#   'awkward': 9,
#   'pause': 15,
#   'returned': 41,
#   'remarkable': 7,
#   'resemblance': 7,
#   'ideas': 12,
#   'us': 105,
#   'hall': 10,
#   'parted': 11,
#   'always': 107,
#   'know': 198,
#   'liberal': 4,
#   'master': 25,
#   'comprehends': 1,
#   'virtue': 10,
#   'why': 45,
#   'forty': 2,
#   'years': 32,
#   'produced': 10,
#   'distributed': 4,
#   'project': 68,
#   'gutenberg': 67,
#   'tm': 44,
#   'ebooks': 5,
#   'loose': 2,
#   'network': 1,
#   'volunteer': 1,
#   'support': 10,
#   'loved': 8,
#   'absurdities': 2,
#   'dance': 27,
#   'ought': 40,
#   'kind': 53,
#   'remark': 3,
#   'size': 4,
#   'couples': 1,
#   'thus': 26,
#   'amusing': 3,
#   'curiosity': 19,
#   'explained': 9,
#   'stubbornness': 1,
#   'bear': 20,
#   'frightened': 6,
#   'severe': 8,
#   'yourself': 38,
#   'adieu': 4,
#   'fancied': 5,
#   'victory': 1,
#   'over': 79,
#   'continued': 44,
#   'times': 18,
#   'play': 16,
#   'really': 73,
#   'unless': 21,
#   'practises': 2,
#   'instrument': 10,
#   'welcome': 11,
#   'often': 73,
#   'rosings': 40,
#   'piano': 5,
#   'forte': 5,
#   'jenkinson': 9,
#   'proper': 20,
#   'wife': 40,
#   'find': 49,
#   'moment': 58,
#   'business': 34,
#   'cannot': 104,
#   'delayed': 5,
#   'instant': 6,
#   'lose': 10,
#   'ease': 15,
#   'perfect': 14,
#   'breeding': 6,
#   'cried': 75,
#   'delightful': 17,
#   'beg': 16,
#   'pardon': 14,
#   'knows': 9,
#   'exactly': 28,
#   'hardly': 38,
#   'written': 17,
#   'affectionate': 15,
#   'behaviour': 44,
#   'another': 49,
#   'ask': 29,
#   'fears': 10,
#   'hither': 3,
#   'recollecting': 4,
#   'chosen': 5,
#   'presented': 2,
#   'smile': 26,
#   'indignation': 6,
#   'perpetual': 1,
#   'commendations': 1,
#   'writing': 15,
#   'evenness': 2,
#   'lines': 9,
#   'letter': 96,
#   'unconcern': 3,
#   'praises': 2,
#   'curious': 4,
#   'dialogue': 2,
#   'unison': 1,
#   'forget': 17,
#   'mama': 2,
#   'meet': 31,
#   'assemblies': 2,
#   'promised': 19,
#   'introduce': 10,
#   'philosophy': 5,
#   'trace': 4,
#   'easily': 23,
#   'clapham': 4,
#   'place': 63,
#   'removed': 17,
#   'hackney': 3,
#   'coach': 10,
#   'dismissed': 3,
#   'epsom': 3,
#   'endeavoured': 7,
#   'secure': 12,
#   'possible': 47,
#   'mildness': 2,
#   'declined': 4,
#   'interfering': 1,
#   'earnestness': 1,
#   'playful': 2,
#   'gaiety': 2,
#   'attacks': 3,
#   'mind': 49,
#   'full': 32,
#   'conversation': 47,
#   'admired': 10,
#   'spot': 7,
#   'point': 39,
#   'view': 14,
#   'seemed': 51,
#   'gratified': 12,
#   'excessive': 4,
#   'admiration': 20,
#   'gracious': 7,
#   'smiles': 10,
#   'especially': 21,
#   'dish': 4,
#   'table': 30,
#   'proved': 14,
#   'novelty': 4,
#   'suspect': 3,
#   'matter': 24,
#   'collinses': 5,
#   'live': 18,
#   'comfortable': 9,
#   'comparison': 12,
#   'assure': 29,
#   'larger': 6,
#   'settled': 44,
#   'leisure': 9,
#   'observe': 7,
#   'old': 12,
#   'friends': 46,
#   'tried': 13,
#   'compose': 3,
#   'patience': 6,
#   'suggested': 4,
#   'accounting': 3,
#   'attentions': 23,
#   'quarter': 6,
#   'partiality': 11,
#   'dispatched': 4,
#   'already': 20,
#   'planned': 3,
#   'courses': 3,
#   'housekeeping': 2,
#   'arrived': 13,
#   'put': 25,
#   'distracted': 2,
#   'expectation': 15,
#   'absolutely': 15,
#   'happiness': 60,
#   'amends': 3,
#   'moments': 9,
#   'painful': 13,
#   'confusion': 11,
#   'company': 18,
#   'listen': 10,
#   'proposal': 8,
#   'carried': 5,
#   'apothecary': 2,
#   'advisable': 6,
#   'doubt': 31,
#   'opening': 12,
#   'perceived': 11,
#   'standing': 11,
#   'together': 55,
#   'hearth': 1,
#   'earnest': 13,
#   'faces': 2,
#   'hastily': 9,
#   'round': 16,
#   'moved': 8,
#   'younger': 22,
#   'anxiety': 13,
#   'under': 35,
#   'suspence': 1,
#   'desirous': 6,
#   'concealing': 1,
#   'alluded': 4,
#   'perceive': 5,
#   'regard': 43,
#   'simpleton': 4,
#   'discover': 8,
#   'manner': 82,
#   'varied': 3,
#   'determination': 3,
#   'elder': 7,
#   'ones': 3,
#   'paid': 19,
#   'ordered': 6,
#   'contrivance': 3,
#   'whole': 72,
#   'party': 49,
#   'boxes': 1,
#   'workbags': 1,
#   'parcels': 2,
#   'unwelcome': 3,
#   'addition': 5,
#   'purchases': 2,
#   'seated': 13,
#   'looked': 63,
#   'surprised': 30,
#   'civility': 34,
#   'increased': 10,
#   'rapidly': 2,
#   'assuring': 3,
#   'latter': 20,
#   'embracing': 2,
#   'tenderly': 2,
#   'shook': 8,
#   'hands': 7,
#   'former': 34,
#   'tell': 58,
#   'unforgiving': 2,
#   ...},
#  2: {'<START> <START>': 5203,
#   '<START> upon': 11,
#   'upon my': 15,
#   'my word': 9,
#   'word said': 2,
#   'said mrs': 18,
#   'mrs gardiner': 48,
#   'gardiner i': 2,
#   'i begin': 3,
#   'begin to': 4,
#   'to be': 359,
#   'be of': 18,
#   'of your': 62,
#   'your uncle': 14,
#   "uncle 's": 7,
#   "'s opinion": 5,
#   'opinion <END>': 9,
#   '<START> elizabeth': 160,
#   'elizabeth was': 54,
#   'was determined': 6,
#   'determined nor': 1,
#   'nor did': 5,
#   'did sir': 1,
#   'sir william': 37,
#   'william at': 1,
#   'at all': 63,
#   'all shake': 1,
#   'shake her': 1,
#   'her purpose': 1,
#   'purpose by': 1,
#   'by his': 32,
#   'his attempt': 1,
#   'attempt at': 3,
#   'at persuasion': 1,
#   'persuasion <END>': 1,
#   '<START> mr': 135,
#   'mr bennet': 77,
#   'bennet you': 3,
#   'you are': 90,
#   'are wanted': 2,
#   'wanted immediately': 1,
#   'immediately we': 1,
#   'we are': 21,
#   'are all': 9,
#   'all in': 7,
#   'in an': 19,
#   'an uproar': 1,
#   'uproar <END>': 1,
#   '<START> but': 267,
#   'but when': 15,
#   'when they': 27,
#   'they see': 1,
#   'see as': 1,
#   'as i': 49,
#   'i trust': 5,
#   'trust they': 2,
#   'they will': 14,
#   'will that': 1,
#   'that their': 15,
#   'their brother': 12,
#   'brother is': 5,
#   'is happy': 2,
#   'happy with': 3,
#   'with me': 15,
#   'me they': 1,
#   'will learn': 1,
#   'learn to': 2,
#   'be contented': 1,
#   'contented and': 1,
#   'and we': 10,
#   'we shall': 19,
#   'shall be': 23,
#   'be on': 4,
#   'on good': 1,
#   'good terms': 1,
#   'terms again': 1,
#   'again though': 1,
#   'though we': 3,
#   'we can': 8,
#   'can never': 8,
#   'never be': 14,
#   'be what': 2,
#   'what we': 8,
#   'we once': 1,
#   'once were': 1,
#   'were to': 31,
#   'to each': 6,
#   'each other': 26,
#   'other <END>': 12,
#   '<START> oh': 69,
#   'oh yes': 6,
#   'yes <END>': 9,
#   'elizabeth at': 3,
#   'at first': 17,
#   'first had': 1,
#   'had rather': 5,
#   'rather wondered': 1,
#   'wondered that': 1,
#   'that charlotte': 8,
#   'charlotte should': 1,
#   'should not': 26,
#   'not prefer': 2,
#   'prefer the': 1,
#   'the dining': 9,
#   'dining parlour': 5,
#   'parlour for': 1,
#   'for common': 1,
#   'common use': 1,
#   'use it': 4,
#   'it was': 221,
#   'was a': 72,
#   'a better': 2,
#   'better sized': 1,
#   'sized room': 1,
#   'room and': 15,
#   'and had': 15,
#   'had a': 28,
#   'a pleasanter': 1,
#   'pleasanter aspect': 1,
#   'aspect but': 1,
#   'but she': 44,
#   'she soon': 10,
#   'soon saw': 2,
#   'saw that': 8,
#   'that her': 39,
#   'her friend': 17,
#   'friend had': 4,
#   'had an': 2,
#   'an excellent': 9,
#   'excellent reason': 1,
#   'reason for': 7,
#   'for what': 8,
#   'what she': 29,
#   'she did': 32,
#   'did for': 2,
#   'for mr': 9,
#   'mr collins': 119,
#   'collins would': 2,
#   'would undoubtedly': 1,
#   'undoubtedly have': 1,
#   'have been': 118,
#   'been much': 2,
#   'much less': 3,
#   'less in': 2,
#   'in his': 67,
#   'his own': 42,
#   'own apartment': 1,
#   'apartment had': 1,
#   'had they': 10,
#   'they sat': 4,
#   'sat in': 2,
#   'in one': 8,
#   'one equally': 1,
#   'equally lively': 1,
#   'lively and': 3,
#   'and she': 99,
#   'she gave': 2,
#   'gave charlotte': 2,
#   'charlotte credit': 1,
#   'credit for': 4,
#   'for the': 135,
#   'the arrangement': 3,
#   'arrangement <END>': 2,
#   '<START> it': 213,
#   'was some': 10,
#   'some days': 2,
#   'days however': 1,
#   'however before': 2,
#   'before they': 15,
#   'they received': 1,
#   'received any': 1,
#   'any invitation': 1,
#   'invitation thither': 1,
#   'thither for': 1,
#   'for while': 2,
#   'while there': 2,
#   'there were': 19,
#   'were visitors': 1,
#   'visitors in': 2,
#   'in the': 339,
#   'the house': 45,
#   'house they': 4,
#   'they could': 18,
#   'could not': 148,
#   'not be': 75,
#   'be necessary': 3,
#   'necessary and': 4,
#   'and it': 34,
#   'was not': 103,
#   'not till': 3,
#   'till easter': 1,
#   'easter day': 1,
#   'day almost': 1,
#   'almost a': 1,
#   'a week': 15,
#   'week after': 2,
#   'after the': 19,
#   'the gentlemen': 13,
#   "gentlemen 's": 3,
#   "'s arrival": 2,
#   'arrival that': 2,
#   'that they': 41,
#   'they were': 109,
#   'were honoured': 2,
#   'honoured by': 1,
#   'by such': 9,
#   'such an': 37,
#   'an attention': 4,
#   'attention and': 5,
#   'and then': 50,
#   'then they': 3,
#   'were merely': 2,
#   'merely asked': 1,
#   'asked on': 1,
#   'on leaving': 2,
#   'leaving church': 1,
#   'church to': 1,
#   'to come': 19,
#   'come there': 3,
#   'there in': 4,
#   'the evening': 44,
#   'evening <END>': 8,
#   'but from': 3,
#   'from the': 80,
#   'the severity': 1,
#   'severity of': 1,
#   'of that': 32,
#   'that blame': 1,
#   'blame which': 1,
#   'which was': 18,
#   'was last': 1,
#   'last night': 9,
#   'night so': 2,
#   'so liberally': 1,
#   'liberally bestowed': 2,
#   'bestowed respecting': 1,
#   'respecting each': 1,
#   'each circumstance': 1,
#   'circumstance i': 1,
#   'i shall': 76,
#   'shall hope': 4,
#   'hope to': 12,
#   'be in': 36,
#   'in future': 5,
#   'future secured': 1,
#   'secured when': 1,
#   'when the': 31,
#   'the following': 15,
#   'following account': 1,
#   'account of': 13,
#   'of my': 68,
#   'my actions': 1,
#   'actions and': 1,
#   'and their': 15,
#   'their motives': 1,
#   'motives has': 1,
#   'has been': 42,
#   'been read': 1,
#   'read <END>': 3,
#   '<START> since': 4,
#   'since her': 5,
#   'her father': 35,
#   "father 's": 16,
#   "'s death": 2,
#   'death her': 1,
#   'her home': 4,
#   'home has': 1,
#   'been london': 1,
#   'london where': 1,
#   'where a': 3,
#   'a lady': 7,
#   'lady lives': 1,
#   'lives with': 2,
#   'with her': 77,
#   'her and': 50,
#   'and superintends': 1,
#   'superintends her': 1,
#   'her education': 2,
#   'education <END>': 4,
#   '<START> yes': 48,
#   'yes there': 2,
#   'there was': 69,
#   'was something': 2,
#   'something in': 5,
#   'in that': 15,
#   'that i': 86,
#   'i told': 9,
#   'told you': 8,
#   'you so': 9,
#   'so from': 2,
#   'the first': 42,
#   'first you': 1,
#   'you may': 36,
#   'may remember': 2,
#   'remember <END>': 1,
#   '<START> i': 507,
#   'i am': 255,
#   'am particularly': 4,
#   'particularly unlucky': 1,
#   'unlucky in': 1,
#   'in meeting': 1,
#   'meeting with': 4,
#   'with a': 76,
#   'a person': 12,
#   'person so': 1,
#   'so well': 18,
#   'well able': 2,
#   'able to': 46,
#   'to expose': 3,
#   'expose my': 1,
#   'my real': 2,
#   'real character': 3,
#   'character in': 1,
#   'in a': 111,
#   'a part': 5,
#   'part of': 37,
#   'of the': 404,
#   'the world': 50,
#   'world where': 1,
#   'where i': 4,
#   'i had': 45,
#   'had hoped': 5,
#   'hoped to': 5,
#   'to pass': 7,
#   'pass myself': 1,
#   'myself off': 1,
#   'off with': 1,
#   'with some': 16,
#   'some degree': 1,
#   'degree of': 14,
#   'of credit': 1,
#   'credit <END>': 2,
#   '<START> and': 148,
#   'and there': 16,
#   'there are': 18,
#   'are several': 2,
#   'several of': 3,
#   'the young': 18,
#   'young men': 10,
#   'men too': 1,
#   'too that': 3,
#   'that she': 114,
#   'she likes': 2,
#   'likes very': 1,
#   'very much': 19,
#   'much <END>': 20,
#   '<START> those': 4,
#   'those who': 9,
#   'who do': 2,
#   'do not': 115,
#   'not complain': 1,
#   'complain are': 1,
#   'are never': 4,
#   'never pitied': 1,
#   'pitied <END>': 1,
#   '<START> to': 47,
#   'to have': 65,
#   'have his': 2,
#   'his errors': 1,
#   'errors made': 1,
#   'made public': 2,
#   'public might': 1,
#   'might ruin': 1,
#   'ruin him': 2,
#   'him for': 8,
#   'for ever': 11,
#   'ever <END>': 13,
#   'it is': 158,
#   'is difficult': 1,
#   'difficult indeed': 1,
#   'indeed it': 3,
#   'is distressing': 1,
#   'distressing <END>': 1,
#   'i thought': 16,
#   'thought i': 4,
#   'i should': 63,
#   'should have': 31,
#   'have broke': 1,
#   'broke my': 1,
#   'my heart': 9,
#   'heart <END>': 9,
#   '<START> after': 32,
#   'after this': 6,
#   'this period': 3,
#   'period every': 1,
#   'every appearance': 2,
#   'appearance of': 12,
#   'of acquaintance': 1,
#   'acquaintance was': 1,
#   'was dropt': 1,
#   'dropt <END>': 1,
#   '<START> when': 59,
#   'when i': 26,
#   'am in': 7,
#   'the country': 28,
#   'country he': 1,
#   'he replied': 12,
#   'replied i': 2,
#   'i never': 30,
#   'never wish': 1,
#   'wish to': 20,
#   'to leave': 14,
#   'leave it': 3,
#   'it and': 29,
#   'and when': 37,
#   'in town': 27,
#   'town it': 1,
#   'is pretty': 1,
#   'pretty much': 3,
#   'much the': 8,
#   'the same': 61,
#   'same <END>': 3,
#   'mr bingley': 99,
#   'bingley was': 24,
#   'was obliged': 6,
#   'obliged to': 20,
#   'town the': 2,
#   'following day': 3,
#   'day and': 7,
#   'and consequently': 5,
#   'consequently unable': 1,
#   'unable to': 13,
#   'to accept': 13,
#   'accept the': 3,
#   'the honour': 20,
#   'honour of': 18,
#   'of their': 76,
#   'their invitation': 2,
#   'invitation c': 1,
#   'c <END>': 9,
#   '<START> she': 279,
#   'she is': 60,
#   'is abominably': 1,
#   'abominably rude': 2,
#   'rude to': 1,
#   'to keep': 9,
#   'keep charlotte': 1,
#   'charlotte out': 1,
#   'out of': 32,
#   'of doors': 3,
#   'doors in': 1,
#   'in all': 20,
#   'all this': 25,
#   'this wind': 1,
#   'wind <END>': 1,
#   'and that': 51,
#   'i suppose': 23,
#   'suppose is': 3,
#   'is one': 5,
#   'one of': 59,
#   'your sisters': 4,
#   'sisters <END>': 12,
#   'i have': 150,
#   'have heard': 13,
#   'heard from': 4,
#   'from authority': 1,
#   'authority which': 1,
#   'which i': 40,
#   'thought as': 1,
#   'as good': 7,
#   'good that': 1,
#   'that it': 56,
#   'was left': 6,
#   'left you': 2,
#   'you conditionally': 1,
#   'conditionally only': 2,
#   'only and': 1,
#   'and at': 19,
#   'at the': 87,
#   'the will': 3,
#   'will of': 5,
#   'the present': 23,
#   'present patron': 1,
#   'patron <END>': 1,
#   'and my': 16,
#   'my mother': 9,
#   'mother how': 1,
#   'how is': 3,
#   'is she': 3,
#   'she <END>': 10,
#   '<START> her': 76,
#   'her carriage': 2,
#   'carriage remained': 1,
#   'remained at': 4,
#   'the door': 24,
#   'door and': 8,
#   'and elizabeth': 44,
#   'elizabeth saw': 6,
#   'her waiting': 1,
#   'waiting woman': 1,
#   'woman was': 1,
#   'was in': 34,
#   'in it': 21,
#   'it <END>': 135,
#   'i rather': 4,
#   'rather expected': 2,
#   'expected from': 1,
#   'from my': 7,
#   'my knowledge': 1,
#   'knowledge of': 12,
#   'of her': 218,
#   'her affability': 1,
#   'affability that': 1,
#   'it would': 53,
#   'would happen': 2,
#   'happen <END>': 4,
#   'she would': 52,
#   'would not': 65,
#   'not give': 9,
#   'give him': 9,
#   'him time': 2,
#   'time to': 14,
#   'to reply': 1,
#   'reply but': 1,
#   'but hurrying': 1,
#   'hurrying instantly': 1,
#   'instantly to': 4,
#   'to her': 153,
#   'her husband': 34,
#   'husband called': 1,
#   'called out': 5,
#   'out as': 5,
#   'as she': 79,
#   'she entered': 6,
#   'entered the': 21,
#   'the library': 11,
#   'library oh': 1,
#   'oh <END>': 54,
#   '<START> we': 53,
#   'we must': 12,
#   'must not': 17,
#   'not all': 6,
#   'all expect': 2,
#   'expect jane': 1,
#   "jane 's": 23,
#   "'s good": 5,
#   'good fortune': 3,
#   'fortune <END>': 4,
#   '<START> that': 52,
#   'that he': 152,
#   'he was': 136,
#   'not a': 26,
#   'a good': 28,
#   'good tempered': 1,
#   'tempered man': 2,
#   'man had': 1,
#   'had been': 171,
#   'been her': 4,
#   'her firmest': 1,
#   'firmest opinion': 1,
#   '<START> he': 199,
#   'was then': 11,
#   'then he': 3,
#   'he said': 11,
#   'said on': 2,
#   'on his': 41,
#   'his way': 1,
#   'way to': 12,
#   'to longbourn': 22,
#   'longbourn on': 3,
#   'on purpose': 4,
#   'purpose to': 4,
#   'to inquire': 2,
#   'inquire after': 1,
#   'after her': 10,
#   'her <END>': 96,
#   '<START> then': 11,
#   'then addressing': 1,
#   'addressing her': 1,
#   'her daughter': 24,
#   'daughter oh': 1,
#   'and this': 9,
#   'this consideration': 1,
#   'consideration leads': 1,
#   'leads me': 2,
#   'me moreover': 1,
#   'moreover to': 2,
#   'to reflect': 1,
#   'reflect with': 2,
#   'with augmented': 1,
#   'augmented satisfaction': 1,
#   'satisfaction on': 1,
#   'on a': 11,
#   'a certain': 7,
#   'certain event': 2,
#   'event of': 5,
#   'of last': 2,
#   'last november': 3,
#   'november for': 1,
#   'for had': 2,
#   'had it': 5,
#   'it been': 4,
#   'been otherwise': 1,
#   'otherwise i': 2,
#   'i must': 37,
#   'must have': 30,
#   'been involved': 1,
#   'involved in': 3,
#   'all your': 5,
#   'your sorrow': 1,
#   'sorrow and': 1,
#   'and disgrace': 1,
#   'disgrace <END>': 2,
#   '<START> the': 224,
#   'the communication': 1,
#   'communication excited': 1,
#   'excited many': 1,
#   'many professions': 1,
#   'professions of': 3,
#   'of concern': 3,
#   'concern and': 5,
#   'and enough': 1,
#   'enough was': 1,
#   'was said': 3,
#   'said of': 8,
#   'of wishing': 1,
#   'wishing them': 1,
#   'them to': 32,
#   'to stay': 9,
#   'stay at': 4,
#   'at least': 32,
#   'least till': 1,
#   'till the': 14,
#   'day to': 3,
#   'to work': 3,
#   'work on': 3,
#   'on jane': 3,
#   'jane and': 21,
#   'and till': 7,
#   'the morrow': 5,
#   'morrow their': 1,
#   'their going': 1,
#   'going was': 1,
#   'was deferred': 1,
#   'deferred <END>': 1,
#   'she had': 171,
#   'had instinctively': 1,
#   'instinctively turned': 1,
#   'turned away': 5,
#   'away but': 3,
#   'but stopping': 1,
#   'stopping on': 1,
#   'his approach': 1,
#   'approach received': 1,
#   'received his': 4,
#   'his compliments': 4,
#   'compliments with': 2,
#   'with an': 30,
#   'an embarrassment': 1,
#   'embarrassment impossible': 1,
#   'impossible to': 7,
#   'be overcome': 2,
#   'overcome <END>': 2,
#   '<START> you': 172,
#   'you never': 3,
#   'never will': 1,
#   'will be': 75,
#   'be able': 15,
#   'to make': 70,
#   'make both': 1,
#   'both of': 6,
#   'of them': 46,
#   'them good': 1,
#   'good for': 2,
#   'for any': 15,
#   'any thing': 67,
#   'thing <END>': 23,
#   'am perfectly': 5,
#   'perfectly convinced': 3,
#   'convinced by': 2,
#   'by it': 5,
#   'it that': 9,
#   'that mr': 31,
#   'mr darcy': 227,
#   'darcy has': 5,
#   'has no': 7,
#   'no defect': 1,
#   'defect <END>': 1,
#   "elizabeth 's": 26,
#   "'s astonishment": 3,
#   'astonishment was': 4,
#   'was beyond': 7,
#   'beyond expression': 2,
#   'expression <END>': 4,
#   '<START> his': 66,
#   'his surprise': 2,
#   'surprise was': 3,
#   'was great': 3,
#   'great <END>': 4,
#   'she was': 169,
#   'was proceeding': 1,
#   'proceeding directly': 1,
#   'directly to': 6,
#   'her favourite': 5,
#   'favourite walk': 2,
#   'walk when': 2,
#   'the recollection': 3,
#   'recollection of': 6,
#   'of mr': 53,
#   "darcy 's": 35,
#   "'s sometimes": 1,
#   'sometimes coming': 1,
#   'coming there': 4,
#   'there stopped': 1,
#   'stopped her': 1,
#   'and instead': 2,
#   'instead of': 18,
#   'of entering': 1,
#   'entering the': 4,
#   'the park': 11,
#   'park she': 1,
#   'she turned': 6,
#   'turned up': 1,
#   'up the': 14,
#   'the lane': 7,
#   'lane which': 1,
#   'which led': 4,
#   'led her': 1,
#   'her farther': 1,
#   'farther from': 2,
#   'the turnpike': 1,
#   'turnpike road': 1,
#   'road <END>': 4,
#   '<START> there': 54,
#   "there 's": 1,
#   "'s for": 2,
#   'for you': 17,
#   'you <END>': 67,
#   'to complete': 2,
#   'complete the': 2,
#   'the favourable': 1,
#   'favourable impression': 1,
#   'impression she': 1,
#   'she then': 14,
#   'then told': 2,
#   'told him': 3,
#   'him what': 2,
#   'what mr': 7,
#   'darcy had': 13,
#   'had voluntarily': 1,
#   'voluntarily done': 1,
#   'done for': 5,
#   'for lydia': 4,
#   'lydia <END>': 13,
#   '<START> my': 108,
#   'my avowed': 1,
#   'avowed one': 1,
#   'one or': 3,
#   'or what': 1,
#   'what i': 39,
#   'i avowed': 1,
#   'avowed to': 1,
#   'to myself': 8,
#   'myself was': 1,
#   'was to': 54,
#   'to see': 60,
#   'see whether': 2,
#   'whether your': 1,
#   'your sister': 16,
#   'sister were': 3,
#   'were still': 6,
#   'still partial': 1,
#   'partial to': 7,
#   'to bingley': 4,
#   'bingley and': 27,
#   'and if': 40,
#   'if she': 25,
#   'she were': 8,
#   'make the': 7,
#   'the confession': 1,
#   'confession to': 2,
#   'to him': 49,
#   'him which': 4,
#   'have since': 1,
#   'since made': 1,
#   'made <END>': 3,
#   'she coloured': 2,
#   'coloured as': 1,
#   'she spoke': 7,
#   'spoke but': 1,
#   'but neither': 2,
#   'neither that': 1,
#   'that nor': 1,
#   'nor any': 2,
#   'thing else': 8,
#   'else awakened': 1,
#   'awakened a': 1,
#   'a suspicion': 2,
#   'suspicion of': 3,
#   'the truth': 13,
#   'truth <END>': 2,
#   'but while': 2,
#   'while he': 7,
#   'was mortal': 1,
#   'mortal there': 1,
#   'there must': 2,
#   'must be': 69,
#   'be a': 31,
#   'a triumph': 2,
#   'triumph <END>': 4,
#   '<START> mrs': 78,
#   'mrs bennet': 129,
#   'bennet was': 31,
#   'was prevented': 1,
#   'prevented replying': 1,
#   'replying by': 1,
#   'by the': 100,
#   'the entrance': 6,
#   'entrance of': 5,
#   'the footman': 1,
#   'footman with': 1,
#   'a note': 2,
#   'note for': 2,
#   'for miss': 3,
#   'miss bennet': 56,
#   'bennet it': 3,
#   'it came': 3,
#   'came from': 4,
#   'from netherfield': 5,
#   'netherfield and': 9,
#   'and the': 135,
#   'the servant': 5,
#   'servant waited': 1,
#   'waited for': 2,
#   'for an': 5,
#   'an answer': 6,
#   'answer <END>': 17,
#   '<START> whatever': 4,
#   'whatever i': 1,
#   'i do': 78,
#   'do is': 1,
#   'is done': 2,
#   'done in': 3,
#   'a hurry': 5,
#   'hurry replied': 1,
#   'replied he': 2,
#   'he and': 6,
#   'and therefore': 10,
#   'therefore if': 1,
#   'if i': 42,
#   'should resolve': 1,
#   'resolve to': 1,
#   'to quit': 3,
#   'quit netherfield': 1,
#   'netherfield i': 1,
#   'should probably': 1,
#   'probably be': 1,
#   'be off': 4,
#   'off in': 3,
#   'in five': 1,
#   'five minutes': 3,
#   'minutes <END>': 2,
#   'am not': 30,
#   'not now': 1,
#   'now to': 5,
#   'to learn': 6,
#   'learn replied': 1,
#   'replied mr': 4,
#   'collins with': 2,
#   'a formal': 2,
#   'formal wave': 1,
#   'wave of': 1,
#   'the hand': 1,
#   'hand that': 2,
#   'is usual': 1,
#   'usual with': 1,
#   'with young': 1,
#   'young ladies': 19,
#   'ladies to': 3,
#   'to reject': 3,
#   'reject the': 2,
#   'the addresses': 1,
#   'addresses of': 1,
#   'the man': 16,
#   'man whom': 6,
#   'whom they': 5,
#   'they secretly': 1,
#   'secretly mean': 1,
#   'mean to': 6,
#   'accept when': 1,
#   'when he': 27,
#   'he first': 4,
#   'first applies': 1,
#   'applies for': 1,
#   'for their': 11,
#   'their favour': 1,
#   'favour and': 3,
#   'that sometimes': 1,
#   'sometimes the': 1,
#   'the refusal': 2,
#   'refusal is': 1,
#   'is repeated': 1,
#   'repeated a': 1,
#   'a second': 11,
#   'second or': 1,
#   'or even': 2,
#   'even a': 3,
#   'a third': 2,
#   'third time': 1,
#   'time <END>': 23,
#   'mr gardiner': 28,
#   'gardiner was': 4,
#   'a sensible': 6,
#   'sensible gentleman': 1,
#   'gentleman like': 8,
#   'like man': 3,
#   'man greatly': 1,
#   'greatly superior': 1,
#   'superior to': 7,
#   'to his': 85,
#   'his sister': 31,
#   'sister as': 5,
#   'as well': 36,
#   'well by': 1,
#   'by nature': 3,
#   'nature as': 2,
#   'as education': 1,
#   'i will': 46,
#   'will read': 1,
#   'read you': 1,
#   'you the': 8,
#   'the passage': 2,
#   'passage which': 1,
#   'which particularly': 1,
#   'particularly hurts': 1,
#   'hurts me': 1,
#   'me <END>': 63,
#   '<START> pursuing': 1,
#   'pursuing her': 1,
#   'her way': 4,
#   'way along': 1,
#   'along the': 4,
#   'lane she': 2,
#   'then began': 2,
#   'began it': 2,
#   '<START> chapter': 46,
#   'chapter xx': 1,
#   'xx mr': 1,
#   'collins was': 18,
#   'not left': 1,
#   'left long': 1,
#   'long to': 4,
#   'to the': 223,
#   'the silent': 2,
#   'silent contemplation': 1,
#   'contemplation of': 3,
#   'of his': 199,
#   'his successful': 1,
#   'successful love': 1,
#   'love for': 3,
#   'for mrs': 6,
#   'bennet having': 1,
#   'having dawdled': 1,
#   'dawdled about': 1,
#   'about in': 3,
#   'the vestibule': 4,
#   'vestibule to': 1,
#   'to watch': 1,
#   'watch for': 1,
#   'the end': 9,
#   'end of': 13,
#   'the conference': 1,
#   'conference no': 1,
#   'no sooner': 8,
#   'sooner saw': 2,
#   'saw elizabeth': 1,
#   'elizabeth open': 1,
#   'open the': 3,
#   'and with': 26,
#   'with quick': 2,
#   'quick step': 2,
#   'step pass': 1,
#   'pass her': 1,
#   'her towards': 1,
#   'towards the': 15,
#   'the staircase': 1,
#   'staircase than': 1,
#   'than she': 20,
#   'the breakfast': 8,
#   'breakfast room': 7,
#   'and congratulated': 1,
#   'congratulated both': 1,
#   'both him': 2,
#   'him and': 36,
#   'and herself': 10,
#   'herself in': 9,
#   'in warm': 1,
#   'warm terms': 1,
#   'terms on': 1,
#   'on the': 131,
#   'the happy': 6,
#   'happy prospect': 1,
#   'prospect of': 9,
#   'their nearer': 1,
#   'nearer connection': 1,
#   'connection <END>': 3,
#   '<START> if': 80,
#   'if you': 70,
#   'you should': 9,
#   'have no': 27,
#   ...},
#  3: {'<START> <START> upon': 11,
#   '<START> upon my': 8,
#   'upon my word': 8,
#   'my word said': 2,
#   'word said mrs': 1,
#   'said mrs gardiner': 4,
#   'mrs gardiner i': 2,
#   'gardiner i begin': 1,
#   'i begin to': 3,
#   'begin to be': 2,
#   'to be of': 7,
#   'be of your': 1,
#   'of your uncle': 2,
#   "your uncle 's": 2,
#   "uncle 's opinion": 1,
#   "'s opinion <END>": 1,
#   '<START> <START> elizabeth': 160,
#   '<START> elizabeth was': 27,
#   'elizabeth was determined': 2,
#   'was determined nor': 1,
#   'determined nor did': 1,
#   'nor did sir': 1,
#   'did sir william': 1,
#   'sir william at': 1,
#   'william at all': 1,
#   'at all shake': 1,
#   'all shake her': 1,
#   'shake her purpose': 1,
#   'her purpose by': 1,
#   'purpose by his': 1,
#   'by his attempt': 1,
#   'his attempt at': 1,
#   'attempt at persuasion': 1,
#   'at persuasion <END>': 1,
#   '<START> <START> mr': 135,
#   '<START> mr bennet': 15,
#   'mr bennet you': 2,
#   'bennet you are': 1,
#   'you are wanted': 1,
#   'are wanted immediately': 1,
#   'wanted immediately we': 1,
#   'immediately we are': 1,
#   'we are all': 2,
#   'are all in': 1,
#   'all in an': 1,
#   'in an uproar': 1,
#   'an uproar <END>': 1,
#   '<START> <START> but': 267,
#   '<START> but when': 8,
#   'but when they': 3,
#   'when they see': 1,
#   'they see as': 1,
#   'see as i': 1,
#   'as i trust': 1,
#   'i trust they': 1,
#   'trust they will': 2,
#   'they will that': 1,
#   'will that their': 1,
#   'that their brother': 2,
#   'their brother is': 2,
#   'brother is happy': 1,
#   'is happy with': 1,
#   'happy with me': 1,
#   'with me they': 1,
#   'me they will': 1,
#   'they will learn': 1,
#   'will learn to': 1,
#   'learn to be': 1,
#   'to be contented': 1,
#   'be contented and': 1,
#   'contented and we': 1,
#   'and we shall': 3,
#   'we shall be': 8,
#   'shall be on': 1,
#   'be on good': 1,
#   'on good terms': 1,
#   'good terms again': 1,
#   'terms again though': 1,
#   'again though we': 1,
#   'though we can': 2,
#   'we can never': 2,
#   'can never be': 4,
#   'never be what': 1,
#   'be what we': 1,
#   'what we once': 1,
#   'we once were': 1,
#   'once were to': 1,
#   'were to each': 1,
#   'to each other': 4,
#   'each other <END>': 7,
#   '<START> <START> oh': 69,
#   '<START> oh yes': 6,
#   'oh yes <END>': 6,
#   '<START> elizabeth at': 2,
#   'elizabeth at first': 1,
#   'at first had': 1,
#   'first had rather': 1,
#   'had rather wondered': 1,
#   'rather wondered that': 1,
#   'wondered that charlotte': 1,
#   'that charlotte should': 1,
#   'charlotte should not': 1,
#   'should not prefer': 1,
#   'not prefer the': 1,
#   'prefer the dining': 1,
#   'the dining parlour': 5,
#   'dining parlour for': 1,
#   'parlour for common': 1,
#   'for common use': 1,
#   'common use it': 1,
#   'use it was': 1,
#   'it was a': 19,
#   'was a better': 1,
#   'a better sized': 1,
#   'better sized room': 1,
#   'sized room and': 1,
#   'room and had': 1,
#   'and had a': 2,
#   'had a pleasanter': 1,
#   'a pleasanter aspect': 1,
#   'pleasanter aspect but': 1,
#   'aspect but she': 1,
#   'but she soon': 1,
#   'she soon saw': 1,
#   'soon saw that': 2,
#   'saw that her': 3,
#   'that her friend': 1,
#   'her friend had': 2,
#   'friend had an': 1,
#   'had an excellent': 1,
#   'an excellent reason': 1,
#   'excellent reason for': 1,
#   'reason for what': 1,
#   'for what she': 1,
#   'what she did': 3,
#   'she did for': 1,
#   'did for mr': 1,
#   'for mr collins': 3,
#   'mr collins would': 2,
#   'collins would undoubtedly': 1,
#   'would undoubtedly have': 1,
#   'undoubtedly have been': 1,
#   'have been much': 1,
#   'been much less': 1,
#   'much less in': 1,
#   'less in his': 1,
#   'in his own': 3,
#   'his own apartment': 1,
#   'own apartment had': 1,
#   'apartment had they': 1,
#   'had they sat': 1,
#   'they sat in': 1,
#   'sat in one': 1,
#   'in one equally': 1,
#   'one equally lively': 1,
#   'equally lively and': 1,
#   'lively and she': 1,
#   'and she gave': 1,
#   'she gave charlotte': 1,
#   'gave charlotte credit': 1,
#   'charlotte credit for': 1,
#   'credit for the': 1,
#   'for the arrangement': 1,
#   'the arrangement <END>': 1,
#   '<START> <START> it': 213,
#   '<START> it was': 78,
#   'it was some': 6,
#   'was some days': 1,
#   'some days however': 1,
#   'days however before': 1,
#   'however before they': 1,
#   'before they received': 1,
#   'they received any': 1,
#   'received any invitation': 1,
#   'any invitation thither': 1,
#   'invitation thither for': 1,
#   'thither for while': 1,
#   'for while there': 1,
#   'while there were': 1,
#   'there were visitors': 1,
#   'were visitors in': 1,
#   'visitors in the': 2,
#   'in the house': 4,
#   'the house they': 3,
#   'house they could': 1,
#   'they could not': 6,
#   'could not be': 28,
#   'not be necessary': 1,
#   'be necessary and': 1,
#   'necessary and it': 1,
#   'and it was': 16,
#   'it was not': 27,
#   'was not till': 3,
#   'not till easter': 1,
#   'till easter day': 1,
#   'easter day almost': 1,
#   'day almost a': 1,
#   'almost a week': 1,
#   'a week after': 2,
#   'week after the': 1,
#   'after the gentlemen': 1,
#   "the gentlemen 's": 3,
#   "gentlemen 's arrival": 1,
#   "'s arrival that": 1,
#   'arrival that they': 1,
#   'that they were': 10,
#   'they were honoured': 2,
#   'were honoured by': 1,
#   'honoured by such': 1,
#   'by such an': 2,
#   'such an attention': 3,
#   'an attention and': 1,
#   'attention and then': 1,
#   'and then they': 3,
#   'then they were': 2,
#   'they were merely': 1,
#   'were merely asked': 1,
#   'merely asked on': 1,
#   'asked on leaving': 1,
#   'on leaving church': 1,
#   'leaving church to': 1,
#   'church to come': 1,
#   'to come there': 2,
#   'come there in': 1,
#   'there in the': 2,
#   'in the evening': 12,
#   'the evening <END>': 5,
#   '<START> but from': 1,
#   'but from the': 1,
#   'from the severity': 1,
#   'the severity of': 1,
#   'severity of that': 1,
#   'of that blame': 1,
#   'that blame which': 1,
#   'blame which was': 1,
#   'which was last': 1,
#   'was last night': 1,
#   'last night so': 2,
#   'night so liberally': 1,
#   'so liberally bestowed': 1,
#   'liberally bestowed respecting': 1,
#   'bestowed respecting each': 1,
#   'respecting each circumstance': 1,
#   'each circumstance i': 1,
#   'circumstance i shall': 1,
#   'i shall hope': 3,
#   'shall hope to': 4,
#   'hope to be': 4,
#   'to be in': 15,
#   'be in future': 1,
#   'in future secured': 1,
#   'future secured when': 1,
#   'secured when the': 1,
#   'when the following': 1,
#   'the following account': 1,
#   'following account of': 1,
#   'account of my': 2,
#   'of my actions': 1,
#   'my actions and': 1,
#   'actions and their': 1,
#   'and their motives': 1,
#   'their motives has': 1,
#   'motives has been': 1,
#   'has been read': 1,
#   'been read <END>': 1,
#   '<START> <START> since': 4,
#   '<START> since her': 2,
#   'since her father': 1,
#   "her father 's": 5,
#   "father 's death": 2,
#   "'s death her": 1,
#   'death her home': 1,
#   'her home has': 1,
#   'home has been': 1,
#   'has been london': 1,
#   'been london where': 1,
#   'london where a': 1,
#   'where a lady': 1,
#   'a lady lives': 1,
#   'lady lives with': 1,
#   'lives with her': 1,
#   'with her and': 3,
#   'her and superintends': 1,
#   'and superintends her': 1,
#   'superintends her education': 1,
#   'her education <END>': 1,
#   '<START> <START> yes': 48,
#   '<START> yes there': 2,
#   'yes there was': 1,
#   'there was something': 2,
#   'was something in': 1,
#   'something in that': 1,
#   'in that i': 1,
#   'that i told': 1,
#   'i told you': 4,
#   'told you so': 1,
#   'you so from': 1,
#   'so from the': 1,
#   'from the first': 2,
#   'the first you': 1,
#   'first you may': 1,
#   'you may remember': 2,
#   'may remember <END>': 1,
#   '<START> <START> i': 507,
#   '<START> i am': 90,
#   'i am particularly': 4,
#   'am particularly unlucky': 1,
#   'particularly unlucky in': 1,
#   'unlucky in meeting': 1,
#   'in meeting with': 1,
#   'meeting with a': 1,
#   'with a person': 1,
#   'a person so': 1,
#   'person so well': 1,
#   'so well able': 1,
#   'well able to': 2,
#   'able to expose': 1,
#   'to expose my': 1,
#   'expose my real': 1,
#   'my real character': 1,
#   'real character in': 1,
#   'character in a': 1,
#   'in a part': 1,
#   'a part of': 5,
#   'part of the': 10,
#   'of the world': 9,
#   'the world where': 1,
#   'world where i': 1,
#   'where i had': 1,
#   'i had hoped': 2,
#   'had hoped to': 2,
#   'hoped to pass': 1,
#   'to pass myself': 1,
#   'pass myself off': 1,
#   'myself off with': 1,
#   'off with some': 1,
#   'with some degree': 1,
#   'some degree of': 1,
#   'degree of credit': 1,
#   'of credit <END>': 1,
#   '<START> <START> and': 148,
#   '<START> and there': 4,
#   'and there are': 4,
#   'there are several': 2,
#   'are several of': 2,
#   'several of the': 2,
#   'of the young': 3,
#   'the young men': 1,
#   'young men too': 1,
#   'men too that': 1,
#   'too that she': 1,
#   'that she likes': 1,
#   'she likes very': 1,
#   'likes very much': 1,
#   'very much <END>': 4,
#   '<START> <START> those': 4,
#   '<START> those who': 2,
#   'those who do': 1,
#   'who do not': 1,
#   'do not complain': 1,
#   'not complain are': 1,
#   'complain are never': 1,
#   'are never pitied': 1,
#   'never pitied <END>': 1,
#   '<START> <START> to': 47,
#   '<START> to have': 1,
#   'to have his': 1,
#   'have his errors': 1,
#   'his errors made': 1,
#   'errors made public': 1,
#   'made public might': 1,
#   'public might ruin': 1,
#   'might ruin him': 1,
#   'ruin him for': 1,
#   'him for ever': 1,
#   'for ever <END>': 8,
#   '<START> it is': 63,
#   'it is difficult': 1,
#   'is difficult indeed': 1,
#   'difficult indeed it': 1,
#   'indeed it is': 1,
#   'it is distressing': 1,
#   'is distressing <END>': 1,
#   '<START> i thought': 7,
#   'i thought i': 4,
#   'thought i should': 2,
#   'i should have': 12,
#   'should have broke': 1,
#   'have broke my': 1,
#   'broke my heart': 1,
#   'my heart <END>': 1,
#   '<START> <START> after': 32,
#   '<START> after this': 2,
#   'after this period': 1,
#   'this period every': 1,
#   'period every appearance': 1,
#   'every appearance of': 2,
#   'appearance of acquaintance': 1,
#   'of acquaintance was': 1,
#   'acquaintance was dropt': 1,
#   'was dropt <END>': 1,
#   '<START> <START> when': 59,
#   '<START> when i': 7,
#   'when i am': 4,
#   'i am in': 7,
#   'am in the': 2,
#   'in the country': 10,
#   'the country he': 1,
#   'country he replied': 1,
#   'he replied i': 1,
#   'replied i never': 1,
#   'i never wish': 1,
#   'never wish to': 1,
#   'wish to leave': 1,
#   'to leave it': 1,
#   'leave it and': 1,
#   'it and when': 1,
#   'and when i': 3,
#   'am in town': 1,
#   'in town it': 1,
#   'town it is': 1,
#   'it is pretty': 1,
#   'is pretty much': 1,
#   'pretty much the': 2,
#   'much the same': 1,
#   'the same <END>': 3,
#   '<START> mr bingley': 13,
#   'mr bingley was': 5,
#   'bingley was obliged': 1,
#   'was obliged to': 6,
#   'obliged to be': 2,
#   'be in town': 2,
#   'in town the': 1,
#   'town the following': 1,
#   'the following day': 3,
#   'following day and': 1,
#   'day and consequently': 1,
#   'and consequently unable': 1,
#   'consequently unable to': 1,
#   'unable to accept': 1,
#   'to accept the': 3,
#   'accept the honour': 1,
#   'the honour of': 17,
#   'honour of their': 1,
#   'of their invitation': 1,
#   'their invitation c': 1,
#   'invitation c <END>': 1,
#   '<START> <START> she': 279,
#   '<START> she is': 22,
#   'she is abominably': 1,
#   'is abominably rude': 1,
#   'abominably rude to': 1,
#   'rude to keep': 1,
#   'to keep charlotte': 1,
#   'keep charlotte out': 1,
#   'charlotte out of': 1,
#   'out of doors': 3,
#   'of doors in': 1,
#   'doors in all': 1,
#   'in all this': 4,
#   'all this wind': 1,
#   'this wind <END>': 1,
#   '<START> and that': 4,
#   'and that i': 2,
#   'that i suppose': 1,
#   'i suppose is': 3,
#   'suppose is one': 1,
#   'is one of': 4,
#   'one of your': 3,
#   'of your sisters': 2,
#   'your sisters <END>': 2,
#   '<START> i have': 41,
#   'i have heard': 7,
#   'have heard from': 1,
#   'heard from authority': 1,
#   'from authority which': 1,
#   'authority which i': 1,
#   'which i thought': 1,
#   'i thought as': 1,
#   'thought as good': 1,
#   'as good that': 1,
#   'good that it': 1,
#   'that it was': 23,
#   'it was left': 2,
#   'was left you': 1,
#   'left you conditionally': 1,
#   'you conditionally only': 1,
#   'conditionally only and': 1,
#   'only and at': 1,
#   'and at the': 6,
#   'at the will': 2,
#   'the will of': 3,
#   'will of the': 2,
#   'of the present': 5,
#   'the present patron': 1,
#   'present patron <END>': 1,
#   '<START> and my': 3,
#   'and my mother': 1,
#   'my mother how': 1,
#   'mother how is': 1,
#   'how is she': 1,
#   'is she <END>': 2,
#   '<START> <START> her': 76,
#   '<START> her carriage': 1,
#   'her carriage remained': 1,
#   'carriage remained at': 1,
#   'remained at the': 2,
#   'at the door': 5,
#   'the door and': 6,
#   'door and elizabeth': 1,
#   'and elizabeth saw': 3,
#   'elizabeth saw that': 2,
#   'that her waiting': 1,
#   'her waiting woman': 1,
#   'waiting woman was': 1,
#   'woman was in': 1,
#   'was in it': 1,
#   'in it <END>': 7,
#   '<START> i rather': 3,
#   'i rather expected': 1,
#   'rather expected from': 1,
#   'expected from my': 1,
#   'from my knowledge': 1,
#   'my knowledge of': 1,
#   'knowledge of her': 1,
#   'of her affability': 1,
#   'her affability that': 1,
#   'affability that it': 1,
#   'that it would': 9,
#   'it would happen': 1,
#   'would happen <END>': 1,
#   '<START> she would': 5,
#   'she would not': 15,
#   'would not give': 6,
#   'not give him': 1,
#   'give him time': 1,
#   'him time to': 2,
#   'time to reply': 1,
#   'to reply but': 1,
#   'reply but hurrying': 1,
#   'but hurrying instantly': 1,
#   'hurrying instantly to': 1,
#   'instantly to her': 1,
#   'to her husband': 4,
#   'her husband called': 1,
#   'husband called out': 1,
#   'called out as': 1,
#   'out as she': 2,
#   'as she entered': 3,
#   'she entered the': 5,
#   'entered the library': 1,
#   'the library oh': 1,
#   'library oh <END>': 1,
#   '<START> <START> we': 53,
#   '<START> we must': 5,
#   'we must not': 4,
#   'must not all': 1,
#   'not all expect': 1,
#   'all expect jane': 1,
#   "expect jane 's": 1,
#   "jane 's good": 1,
#   "'s good fortune": 1,
#   'good fortune <END>': 1,
#   '<START> <START> that': 52,
#   '<START> that he': 7,
#   'that he was': 29,
#   'he was not': 5,
#   'was not a': 4,
#   'not a good': 1,
#   'a good tempered': 1,
#   'good tempered man': 1,
#   'tempered man had': 1,
#   'man had been': 1,
#   'had been her': 2,
#   'been her firmest': 1,
#   'her firmest opinion': 1,
#   'firmest opinion <END>': 1,
#   '<START> <START> he': 199,
#   '<START> he was': 29,
#   'he was then': 1,
#   'was then he': 1,
#   'then he said': 1,
#   'he said on': 1,
#   'said on his': 1,
#   'on his way': 1,
#   'his way to': 1,
#   'way to longbourn': 2,
#   'to longbourn on': 2,
#   'longbourn on purpose': 1,
#   'on purpose to': 4,
#   'purpose to inquire': 1,
#   'to inquire after': 1,
#   'inquire after her': 1,
#   'after her <END>': 3,
#   '<START> <START> then': 11,
#   '<START> then addressing': 1,
#   'then addressing her': 1,
#   'addressing her daughter': 1,
#   'her daughter oh': 1,
#   'daughter oh <END>': 1,
#   '<START> and this': 4,
#   'and this consideration': 1,
#   'this consideration leads': 1,
#   'consideration leads me': 1,
#   'leads me moreover': 1,
#   'me moreover to': 1,
#   'moreover to reflect': 1,
#   'to reflect with': 1,
#   'reflect with augmented': 1,
#   'with augmented satisfaction': 1,
#   'augmented satisfaction on': 1,
#   'satisfaction on a': 1,
#   'on a certain': 1,
#   'a certain event': 2,
#   'certain event of': 2,
#   'event of last': 1,
#   'of last november': 1,
#   'last november for': 1,
#   'november for had': 1,
#   'for had it': 1,
#   'had it been': 3,
#   'it been otherwise': 1,
#   'been otherwise i': 1,
#   'otherwise i must': 1,
#   'i must have': 5,
#   'must have been': 9,
#   'have been involved': 1,
#   'been involved in': 1,
#   'involved in all': 1,
#   'in all your': 1,
#   'all your sorrow': 1,
#   'your sorrow and': 1,
#   'sorrow and disgrace': 1,
#   'and disgrace <END>': 1,
#   '<START> <START> the': 224,
#   '<START> the communication': 1,
#   'the communication excited': 1,
#   'communication excited many': 1,
#   'excited many professions': 1,
#   'many professions of': 1,
#   'professions of concern': 1,
#   'of concern and': 2,
#   'concern and enough': 1,
#   'and enough was': 1,
#   'enough was said': 1,
#   'was said of': 1,
#   'said of wishing': 1,
#   'of wishing them': 1,
#   'wishing them to': 1,
#   'them to stay': 3,
#   'to stay at': 1,
#   'stay at least': 1,
#   'at least till': 1,
#   'least till the': 1,
#   'till the following': 1,
#   'following day to': 1,
#   'day to work': 1,
#   'to work on': 1,
#   'work on jane': 1,
#   'on jane and': 1,
#   'jane and till': 1,
#   'and till the': 3,
#   'till the morrow': 1,
#   'the morrow their': 1,
#   'morrow their going': 1,
#   'their going was': 1,
#   'going was deferred': 1,
#   'was deferred <END>': 1,
#   '<START> she had': 33,
#   'she had instinctively': 1,
#   'had instinctively turned': 1,
#   'instinctively turned away': 1,
#   'turned away but': 1,
#   'away but stopping': 1,
#   'but stopping on': 1,
#   'stopping on his': 1,
#   'on his approach': 1,
#   'his approach received': 1,
#   'approach received his': 1,
#   'received his compliments': 1,
#   'his compliments with': 2,
#   'compliments with an': 1,
#   'with an embarrassment': 1,
#   'an embarrassment impossible': 1,
#   'embarrassment impossible to': 1,
#   'impossible to be': 2,
#   'to be overcome': 1,
#   'be overcome <END>': 1,
#   '<START> <START> you': 172,
#   '<START> you never': 1,
#   'you never will': 1,
#   'never will be': 1,
#   'will be able': 1,
#   'be able to': 15,
#   'able to make': 4,
#   'to make both': 1,
#   'make both of': 1,
#   'both of them': 3,
#   'of them good': 1,
#   'them good for': 1,
#   'good for any': 1,
#   'for any thing': 4,
#   'any thing <END>': 9,
#   'i am perfectly': 5,
#   'am perfectly convinced': 1,
#   'perfectly convinced by': 1,
#   'convinced by it': 1,
#   'by it that': 2,
#   'it that mr': 2,
#   'that mr darcy': 11,
#   'mr darcy has': 3,
#   'darcy has no': 1,
#   'has no defect': 1,
#   'no defect <END>': 1,
#   "<START> elizabeth 's": 7,
#   "elizabeth 's astonishment": 1,
#   "'s astonishment was": 2,
#   'astonishment was beyond': 1,
#   'was beyond expression': 1,
#   'beyond expression <END>': 2,
#   '<START> oh <END>': 49,
#   '<START> <START> his': 66,
#   '<START> his surprise': 1,
#   'his surprise was': 1,
#   'surprise was great': 1,
#   'was great <END>': 2,
#   '<START> she was': 41,
#   'she was proceeding': 1,
#   'was proceeding directly': 1,
#   'proceeding directly to': 1,
#   'directly to her': 1,
#   'to her favourite': 1,
#   'her favourite walk': 2,
#   'favourite walk when': 1,
#   'walk when the': 1,
#   'when the recollection': 1,
#   'the recollection of': 3,
#   'recollection of mr': 1,
#   'of mr darcy': 23,
#   "mr darcy 's": 24,
#   "darcy 's sometimes": 1,
#   "'s sometimes coming": 1,
#   'sometimes coming there': 1,
#   'coming there stopped': 1,
#   'there stopped her': 1,
#   'stopped her and': 1,
#   'her and instead': 1,
#   'and instead of': 2,
#   'instead of entering': 1,
#   'of entering the': 1,
#   'entering the park': 1,
#   'the park she': 1,
#   'park she turned': 1,
#   'she turned up': 1,
#   'turned up the': 1,
#   'up the lane': 1,
#   'the lane which': 1,
#   'lane which led': 1,
#   'which led her': 1,
#   'led her farther': 1,
#   'her farther from': 1,
#   'farther from the': 2,
#   'from the turnpike': 1,
#   'the turnpike road': 1,
#   'turnpike road <END>': 1,
#   '<START> <START> there': 54,
#   "<START> there 's": 1,
#   "there 's for": 1,
#   "'s for you": 1,
#   'for you <END>': 6,
#   '<START> to complete': 1,
#   'to complete the': 2,
#   'complete the favourable': 1,
#   'the favourable impression': 1,
#   'favourable impression she': 1,
#   'impression she then': 1,
#   'she then told': 1,
#   'then told him': 1,
#   'told him what': 1,
#   'him what mr': 1,
#   'what mr darcy': 4,
#   'mr darcy had': 10,
#   'darcy had voluntarily': 1,
#   'had voluntarily done': 1,
#   'voluntarily done for': 1,
#   'done for lydia': 2,
#   'for lydia <END>': 1,
#   '<START> <START> my': 108,
#   '<START> my avowed': 1,
#   'my avowed one': 1,
#   'avowed one or': 1,
#   'one or what': 1,
#   'or what i': 1,
#   'what i avowed': 1,
#   'i avowed to': 1,
#   'avowed to myself': 1,
#   'to myself was': 1,
#   'myself was to': 1,
#   'was to see': 2,
#   'to see whether': 2,
#   'see whether your': 1,
#   'whether your sister': 1,
#   'your sister were': 1,
#   'sister were still': 1,
#   'were still partial': 1,
#   'still partial to': 1,
#   'partial to bingley': 1,
#   'to bingley and': 1,
#   'bingley and if': 1,
#   'and if she': 6,
#   'if she were': 3,
#   'she were to': 2,
#   'were to make': 1,
#   'to make the': 3,
#   'make the confession': 1,
#   'the confession to': 1,
#   'confession to him': 2,
#   'to him which': 3,
#   'him which i': 3,
#   'which i have': 5,
#   'i have since': 1,
#   'have since made': 1,
#   'since made <END>': 1,
#   '<START> she coloured': 1,
#   'she coloured as': 1,
#   'coloured as she': 1,
#   'as she spoke': 2,
#   'she spoke but': 1,
#   'spoke but neither': 1,
#   'but neither that': 1,
#   'neither that nor': 1,
#   'that nor any': 1,
#   'nor any thing': 1,
#   'any thing else': 5,
#   'thing else awakened': 1,
#   'else awakened a': 1,
#   'awakened a suspicion': 1,
#   'a suspicion of': 2,
#   'suspicion of the': 1,
#   'of the truth': 4,
#   'the truth <END>': 1,
#   '<START> but while': 1,
#   'but while he': 1,
#   'while he was': 3,
#   'he was mortal': 1,
#   'was mortal there': 1,
#   'mortal there must': 1,
#   'there must be': 2,
#   'must be a': 6,
#   'be a triumph': 1,
#   'a triumph <END>': 1,
#   '<START> <START> mrs': 78,
#   '<START> mrs bennet': 44,
#   'mrs bennet was': 19,
#   'bennet was prevented': 1,
#   'was prevented replying': 1,
#   'prevented replying by': 1,
#   'replying by the': 1,
#   'by the entrance': 4,
#   'the entrance of': 4,
#   'entrance of the': 1,
#   'of the footman': 1,
#   'the footman with': 1,
#   'footman with a': 1,
#   'with a note': 1,
#   'a note for': 1,
#   'note for miss': 1,
#   'for miss bennet': 2,
#   'miss bennet it': 3,
#   'bennet it came': 2,
#   'it came from': 2,
#   'came from netherfield': 2,
#   'from netherfield and': 2,
#   'netherfield and the': 1,
#   'and the servant': 1,
#   'the servant waited': 1,
#   'servant waited for': 1,
#   'waited for an': 1,
#   'for an answer': 1,
#   'an answer <END>': 2,
#   '<START> <START> whatever': 4,
#   '<START> whatever i': 1,
#   'whatever i do': 1,
#   'i do is': 1,
#   'do is done': 1,
#   'is done in': 1,
#   'done in a': 2,
#   'in a hurry': 4,
#   'a hurry replied': 1,
#   'hurry replied he': 1,
#   'replied he and': 1,
#   'he and therefore': 1,
#   'and therefore if': 1,
#   'therefore if i': 1,
#   'if i should': 2,
#   'i should resolve': 1,
#   'should resolve to': 1,
#   'resolve to quit': 1,
#   'to quit netherfield': 1,
#   'quit netherfield i': 1,
#   'netherfield i should': 1,
#   'i should probably': 1,
#   'should probably be': 1,
#   'probably be off': 1,
#   'be off in': 1,
#   'off in five': 1,
#   'in five minutes': 1,
#   'five minutes <END>': 1,
#   'i am not': 29,
#   'am not now': 1,
#   'not now to': 1,
#   'now to learn': 1,
#   'to learn replied': 1,
#   'learn replied mr': 1,
#   'replied mr collins': 2,
#   'mr collins with': 2,
#   'collins with a': 1,
#   'with a formal': 1,
#   'a formal wave': 1,
#   'formal wave of': 1,
#   'wave of the': 1,
#   'of the hand': 1,
#   'the hand that': 1,
#   'hand that it': 1,
#   'that it is': 4,
#   'it is usual': 1,
#   'is usual with': 1,
#   'usual with young': 1,
#   'with young ladies': 1,
#   'young ladies to': 2,
#   'ladies to reject': 1,
#   'to reject the': 2,
#   'reject the addresses': 1,
#   'the addresses of': 1,
#   'addresses of the': 1,
#   'of the man': 4,
#   'the man whom': 4,
#   'man whom they': 2,
#   'whom they secretly': 1,
#   'they secretly mean': 1,
#   'secretly mean to': 1,
#   'mean to accept': 1,
#   'to accept when': 1,
#   'accept when he': 1,
#   'when he first': 3,
#   'he first applies': 1,
#   'first applies for': 1,
#   'applies for their': 1,
#   'for their favour': 1,
#   'their favour and': 1,
#   'favour and that': 1,
#   'and that sometimes': 1,
#   'that sometimes the': 1,
#   'sometimes the refusal': 1,
#   'the refusal is': 1,
#   'refusal is repeated': 1,
#   'is repeated a': 1,
#   'repeated a second': 1,
#   'a second or': 1,
#   'second or even': 1,
#   'or even a': 1,
#   'even a third': 2,
#   'a third time': 1,
#   'third time <END>': 1,
#   '<START> mr gardiner': 10,
#   'mr gardiner was': 1,
#   'gardiner was a': 1,
#   'was a sensible': 1,
#   'a sensible gentleman': 1,
#   'sensible gentleman like': 1,
#   'gentleman like man': 3,
#   'like man greatly': 1,
#   'man greatly superior': 1,
#   'greatly superior to': 1,
#   'superior to his': 1,
#   'to his sister': 6,
#   'his sister as': 2,
#   'sister as well': 1,
#   'as well by': 1,
#   'well by nature': 1,
#   'by nature as': 1,
#   'nature as education': 1,
#   'as education <END>': 1,
#   '<START> i will': 20,
#   'i will read': 1,
#   'will read you': 1,
#   'read you the': 1,
#   'you the passage': 1,
#   'the passage which': 1,
#   'passage which particularly': 1,
#   'which particularly hurts': 1,
#   'particularly hurts me': 1,
#   'hurts me <END>': 1,
#   '<START> <START> pursuing': 1,
#   '<START> pursuing her': 1,
#   'pursuing her way': 1,
#   'her way along': 1,
#   'way along the': 1,
#   'along the lane': 2,
#   'the lane she': 2,
#   ...}}

# %%
plt.plot(np.log(list(lm.nr.keys())),np.log(list(lm.nr.values())), 'b+')
plt.plot(np.log(list(lm.nr.keys())),lr.slope*np.log(list(lm.nr.keys()))+lr.intercept, 'r+')

# %%
plt.plot(list(lm.nr.keys())[:-10],list(lm.nr.values())[:-10], 'b+')
plt.plot(list(lm.nr.keys())[:-10],np.exp(lr.slope*np.log(list(lm.nr.keys())[:-10])+lr.intercept), 'r+')

# %%
lm.nr
# Out:
# {270: 1,
#  208: 1,
#  86: 1,
#  121: 1,
#  154: 1,
#  323: 1,
#  38: 1,
#  63: 1,
#  79: 1,
#  83: 1,
#  61: 1,
#  76: 1,
#  620: 1,
#  248: 1,
#  126: 1,
#  54: 1,
#  89: 1,
#  328: 1,
#  239: 1,
#  88: 1,
#  91: 1,
#  110: 1,
#  99: 1,
#  167: 1,
#  51: 1,
#  80: 1,
#  196: 1,
#  65: 1,
#  55: 1,
#  36: 1,
#  50: 2,
#  37: 2,
#  74: 2,
#  33: 2,
#  41: 2,
#  53: 2,
#  56: 2,
#  49: 2,
#  40: 3,
#  57: 3,
#  27: 3,
#  35: 3,
#  32: 4,
#  34: 4,
#  28: 4,
#  26: 4,
#  25: 4,
#  24: 4,
#  31: 5,
#  21: 5,
#  62: 5,
#  30: 5,
#  22: 9,
#  23: 10,
#  18: 12,
#  19: 16,
#  20: 16,
#  17: 16,
#  16: 19,
#  15: 22,
#  14: 38,
#  12: 40,
#  13: 45,
#  11: 47,
#  10: 64,
#  9: 83,
#  8: 116,
#  7: 186,
#  6: 280,
#  5: 455,
#  4: 842,
#  3: 1964,
#  2: 6948,
#  1: 90879}
